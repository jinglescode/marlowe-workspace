# %%
import sqlalchemy
import pandas as pd

# %%
engine = sqlalchemy.create_engine('postgresql://jingles:@127.0.0.1:5432/marlowe')
print(engine)
# Out:
# Engine(postgresql://jingles:***@127.0.0.1:5432/marlowe)

# %%
df = pd.read_sql('SELECT * FROM marlowe.marlowe_contracttxout', engine)
df
# Out:
#                                                     txid  txix  \
# 0      [b'\xf0', b'n', b'K', b'v', b'\x0f', b'-', b'\...     1
# 1      [b'\t', b'\xce', b'\xef', b'\xb3', b'\x86', b'...     1
# 2      [b'y', b'}', b'\xe2', b'v', b'\xe4', b'\x84', ...     1
# 3      [b'\xd0', b'\xd2', b'\x1d', b'\x80', b'J', b'\...     1
# 4      [b'\xa7', b'3', b'\n', b'N', b'\x1d', b'\\', b...     1
# ...                                                  ...   ...
# 31141  [b'r', b'\x97', b'C', b'\xc7', b')', b'\xb6', ...     1
# 31142  [b']', b'\xdf', b',', b'\x8c', b'*', b'\x86', ...     1
# 31143  [b'\x19', b'F', b'\x1f', b'\xc3', b':', b'W', ...     1
# 31144  [b'\x06', b'\x8b', b'L', b'[', b'l', b'(', b't...     1
# 31145  [b'\x96', b'&', b'\xdb', b'\xa4', b'a', b'\x8b...     1
#
#                                                  blockid  \
# 0      [b'\xf7', b')', b'\xf5', b'{', b';', b'\xd9', ...
# 1      [b'*', b'\x18', b'\x1d', b'\x0c', b'.', b'\x06...
# ...

# %%
load(df.contract_hex[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 load(df.contract_hex[0])
#
# ValueError: fp object must have a callable read method

# %%
from cbor2 import dumps, loads, load, dump

data = dumps(['hello', 'world'])
print(data)
print(type(data))

obj = loads(data)
print(obj)
# Out:
# b'\x82ehelloeworld'
# <class 'bytes'>
# ['hello', 'world']

# %%
for i in range(2):
  data = df.contract[i]
  data = bytes(data)
  print(type(data))
  print(data)
  obj = loads(data)
  print(obj)
  print()
# Out:
# <class 'bytes'>
# ...

# %%
hex1 = "..."
obj = loads(hex1)
print(obj)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 hex1 = "[..."
# ----> 2 obj = loads(hex1)
#       3 print(obj)
#
# TypeError: a bytes-like object is required, not 'str'

# %%
from pycardano import Address, Network, PaymentSigningKey, PaymentVerificationKey, PlutusData, PlutusV2Script

# %%
# class MyDatum(PlutusData):
#     def __init__(self, value):
#         super().__init__(value)

#     def to_bytes(self):
#         return self.value.encode('utf-8')

#     @classmethod
#     def from_bytes(cls, bytes):
#         return cls(bytes.decode('utf-8'))

# datum = MyDatum(b"1234")
# datum.to_cbor_hex()

datum = PlutusData({'b':b"1234"})
datum.to_cbor_hex()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 15
#       1 # class MyDatum(PlutusData):
#       2 #     def __init__(self, value):
#       3 #         super().__init__(value)
#    (...)
#      12 # datum = MyDatum(b"1234")
#      13 # datum.to_cbor_hex()
# ---> 15 datum = PlutusData({'b':b"1234"})
#      16 datum.to_cbor_hex()
#
# TypeError: __init__() takes 1 positional argument but 2 were given

# %%
engine = sqlalchemy.create_engine('postgresql://jingles:@127.0.0.1:5432/chain')
print(engine)
# Out:
# Engine(postgresql://jingles:***@127.0.0.1:5432/chain)

# %%
df = pd.read_sql('SELECT * FROM chain.chain_txout WHERE txid_hex=\'f06e4b760f2d9578c8088ea5289ba6276e68ae3cbaf5ad27bcfc77dc413890db\'', engine)
df
# Out:
#                                                 txid  txix    slotno  \
# 0  [b'\xf0', b'n', b'K', b'v', b'\x0f', b'-', b'\...     0  11630746
# 1  [b'\xf0', b'n', b'K', b'v', b'\x0f', b'-', b'\...     1  11630746
#
#                                              address   lovelace  \
# 0  [b'`', b']', b'\xcf', b'N', b'\xdf', b'\xb4', ...  246785395
# 1  [b'p', b'j', b'\x93', b'\x91', b'\xd6', b'\xaa...    3000000
#
#                                            datumhash  \
# 0                                               None
# 1  [b'\x0e', b'\x1e', b'\xd8', b'(', b'\xc4', b'\...
#
#                                           datumbytes  iscollateral  \
# 0                                               None         False
# 1  [b'\xd8', b'y', b'\x9f', b'\xd8', b'y', b'\x9f...         False
#
#   addressheader                           addresspaymentcredential  \
# 0        [b'`']  [b']', b'\xcf', b'N', b'\xdf', b'\xb4', b'N', ...
# ...

# %%
data = df.datumbytes[1]
data = bytes(data)
print(type(data))
print(data)
obj = loads(data)
print(obj)
print(type(obj))
print()
# Out:
# <class 'bytes'>
# ...

# %%
df = pd.read_sql('SELECT * FROM chain.chain_txout WHERE txid_hex=\'d0d21d804a17ad6d07bc1f9ef690f8dcaa505e7451fc1dd9eaaed1bc67177e2b\'', engine)


data = df.datumbytes[1]
data = bytes(data)
print(type(data))
print(data)
obj = loads(data)
print(obj)
print(type(obj))
print()
# Out:
# <class 'bytes'>
# b'\xd8y\x9f\xd8y\x9f@\xff\xd8y\x9f\xa1\xd8y\x9f\xd8y\x9f\xd8y\x80\xd8y\x9f\xd8y\x9fX\x1c]\xcfN\xdf\xb4N\x98\xac5 \xfdB\xfe\x10\xed\x90\xeb\xafd\x08\xef\xdc\x9b\xecl{"\x9a\xff\xd8z\x80\xff\xff\xd8y\x9f@@\xff\xff\x1a\x00\x1e\x84\x80\xa0\xa0\x00\xff\xd8y\x80\xff'
# CBORTag(121, [CBORTag(121, [b'']), CBORTag(121, [{CBORTag(121, (CBORTag(121, (CBORTag(121, ()), CBORTag(121, (CBORTag(121, (b']\xcfN\xdf\xb4N\x98\xac5 \xfdB\xfe\x10\xed\x90\xeb\xafd\x08\xef\xdc\x9b\xecl{"\x9a',)), CBORTag(122, ()))))), CBORTag(121, (b'', b'')))): 2000000}, {}, {}, 0]), CBORTag(121, [])])
# <class '_cbor2.CBORTag'>

# %%
# given_string = '...'
given_string = 'd8799fd8799f40ffd8799fa1d8799fd8799fd87980d8799fd8799f581c1cb51be3ab4e4b540e86bd4c9be02682db8150f69c3cded2422cc1bfffd87a80ffffd8799f4040ffff1a001e8480a0a000ffd87980ff'
n = 2
words = [(given_string[i:i+n]) for i in range(0, len(given_string), n)]
sentence = ' '.join(words)
sentence
# Out:
# 'd8 79 9f d8 79 9f 40 ff d8 79 9f a1 d8 79 9f d8 79 9f d8 79 80 d8 79 9f d8 79 9f 58 1c 1c b5 1b e3 ab 4e 4b 54 0e 86 bd 4c 9b e0 26 82 db 81 50 f6 9c 3c de d2 42 2c c1 bf ff d8 7a 80 ff ff d8 79 9f 40 40 ff ff 1a 00 1e 84 80 a0 a0 00 ff d8 79 80 ff'

# %%
word_count = {}
for word in words:
    if word not in word_count:
        word_count[word] = 1
    elif word in word_count:
        word_count[word] += 1

word_count
# Out:
# {'d8': 11,
#  '79': 10,
#  '9f': 8,
#  '40': 3,
#  'ff': 8,
#  'a1': 1,
#  '80': 4,
#  '58': 1,
#  '1c': 2,
#  'b5': 1,
#  '1b': 1,
#  'e3': 1,
#  'ab': 1,
#  '4e': 1,
#  '4b': 1,
#  '54': 1,
#  '0e': 1,
#  '86': 1,
#  'bd': 1,
#  '4c': 1,
#  '9b': 1,
#  'e0': 1,
#  '26': 1,
#  '82': 1,
#  'db': 1,
#  '81': 1,
#  '50': 1,
#  'f6': 1,
#  '9c': 1,
#  '3c': 1,
#  'de': 1,
#  'd2': 1,
#  '42': 1,
#  '2c': 1,
#  'c1': 1,
#  'bf': 1,
#  '7a': 1,
#  '1a': 1,
#  '00': 2,
#  '1e': 1,
#  '84': 1,
#  'a0': 2}
